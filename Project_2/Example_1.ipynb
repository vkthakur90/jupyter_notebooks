# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(start = -100, stop = 100, num = 200 * 10 + 1, endpoint = True)
y = np.cos(2 * np.pi * x/25)

# %%
plt.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
