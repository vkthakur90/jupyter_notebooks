# %% [markdown]
# <a href="https://colab.research.google.com/github/vkthakur90/jupyter_notebooks/blob/master/Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade keras-cv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 53.6 MB/s eta 0:00:00

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512, jit_compile = True)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
def get_image(prompt):
    images = model.text_to_image(
        prompt = prompt,
        num_steps = 100,
        unconditional_guidance_scale = 7
    )

    img = keras.utils.array_to_img(images[0])

    return img

# %%
img = get_image('tiger')
# Out:
# 100/100 [==============================] - 81s 807ms/step

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
